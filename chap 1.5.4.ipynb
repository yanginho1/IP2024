# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ##### Introduction to SIFT (Scale-Invariant Feature Transform

# %%
img = cv2.imread('sIMG_2164.jpg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_keypoints.jpg',img)
# Out:
# True

# %%
plt.imshow(img)

# %%
img = cv2.imread('view1.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_view1.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('view5.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_view5.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('view1-1.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_view1-1.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('view5-5.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_view5-5.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('Motorcycle.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_Motorcycle.jpg',img)

plt.imshow(img)

# %%
img = cv2.imread('Motorcycle-1.png')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)

img=cv2.drawKeypoints(gray,kp,img)

cv2.imwrite('sift_Motorcycle-1.jpg',img)

plt.imshow(img)
